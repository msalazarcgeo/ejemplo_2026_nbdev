# %%
#| hide
from ejemplo_2026_nbdev.core import *

# %% [markdown]
# # ejemplo_2026_nbdev
#
# > Un repositorio de prueba

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install ejemplo_2026_nbdev in Development mode

# %% [markdown]
# ```sh
# # make sure ejemplo_2026_nbdev package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to ejemplo_2026_nbdev
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/msalazarcgeo/ejemplo_2026_nbdev.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c msalazarcgeo ejemplo_2026_nbdev
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install ejemplo_2026_nbdev
# ```
#
#
# [repo]: https://github.com/msalazarcgeo/ejemplo_2026_nbdev
# [docs]: https://msalazarcgeo.github.io/ejemplo_2026_nbdev/
# [pypi]: https://pypi.org/project/ejemplo_2026_nbdev/
# [conda]: https://anaconda.org/msalazarcgeo/ejemplo_2026_nbdev

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/msalazarcgeo/ejemplo_2026_nbdev
# [docs]: https://msalazarcgeo.github.io/ejemplo_2026_nbdev/
# [pypi]: https://pypi.org/project/ejemplo_2026_nbdev/
# [conda]: https://anaconda.org/msalazarcgeo/ejemplo_2026_nbdev

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
